# %% [markdown]
# # Generate results summary files
#
# This notebook is the master notebook that runs all of the results summary notebooks that create the figures and tables used in the paper.
#
# > Figures are saved to `paper/figures` and tables to `paper/tables`

# %% [markdown]
# ## Model Selection Stage 2.

# %%
# %run ./create_model_selection_s2_summary.ipynb
# Out:
# Figure 4: Cross-validation variation in Prediction Interval Coverage across regions by horizon

# %%
# %run ./create_benchmark_tables.ipynb
# Out:
# ['Cornwall-fbp-arima_mase_mean', 'Devon-fbp-arima_mase_mean', 'Dorset-fbp-arima_mase_mean', 'Wiltshire-fbp-arima_mase_mean', 'BNSSG-fbp-arima_mase_mean', 'Gloucestershire-fbp-arima_mase_mean', 'Somerset-fbp-arima_mase_mean']
# 0.6784974924174417
# 0.674071541040046 0.6829234437948375
# 0.6754651190449112
# 0.15553071492201298
# 0.4862189431844665
# 0.9111552030310656
# 4.5651094055864005
# 1.2627920461720255
# 4.309243956042549 4.8209748551302525
# 4.1686802924394435
# 1.6189725934945747
# 2.553448199320979
# 6.665200093721894
# 0.8439987608895493
# 0.8401833233918973 0.8478141983872013
# 0.8495934959349594
# 0.023606271777003474
# 0.8048158287705326
# 0.8653455284552847
# 0.9644129013085894
# 0.9626064941466586 0.9662193084705202
# 0.9648664343786295
# 0.010585886239195874
# 0.9465473550839404
# 0.9749564459930317
